# %%
import pandas as pd
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt


with open('/Users/sports195admin/Desktop/rxch/SOClistPython/SOClist.txt', 'r') as infile:
    soc_dict = {}
    contents = infile.readlines() #readlines returns all lines as a python list

    for line in contents: # iterates thru every element in list
        code = line[:7]
        #print('"{}"'.format(code))
        occupation = line.strip()[8:]
        first_key = code[:2] # gets first two nums of line
        second_key = code[3]

        if not first_key in soc_dict:
            soc_dict[first_key] = {}

        if not second_key in soc_dict[first_key]:
            soc_dict[first_key][second_key] = {"label":None, "SOC":[]}
            
        if code[-3:] == "000":
           # print(occupation)
            soc_dict[first_key][second_key]["label"] = occupation
            
        else:
            soc_dict[first_key][second_key]["SOC"].append((code, occupation))
       # break

# %%
"11-1000"[-3:]=="000"
# Out:
# True

# %%
soc_dict["13"]
# Out:
# {'0': {'SOC': [], 'label': 'Business and Financial Operations Occupations'},
#  '1': {'SOC': [('13-1010',
#     'Agents and Business Managers of Artists, Performers, and Athletes'),
#    ('13-1011',
#     'Agents and Business Managers of Artists, Performers, and Athletes'),
#    ('13-1011', 'Agents of Artists'),
#    ('13-1011', 'Agents of Athletes'),
#    ('13-1011', 'Agents of Performers'),
#    ('13-1011', 'Agents, Literary'),
#    ('13-1011', 'Agents, Theatrical'),
#    ('13-1011', 'Artists Agents'),
#    ('13-1011', 'Artists Business Managers'),
#    ('13-1011', 'Athletes Agents'),
#    ('13-1011', 'Band Managers'),
#    ('13-1011', 'Business Managers of Artists'),
#    ('13-1011', 'Business Managers of Athletes'),
#    ('13-1011', 'Business Managers of Performers'),
#    ('13-1011', 'Literary Agents'),
#    ('13-1011', 'Managers, Band'),
#    ('13-1011', 'Performers Agents'),
#    ('13-1011', 'Performers Business Managers'),
#    ('13-1011', 'Theatrical Agents'),
#    ('13-1020', 'Buyers and Purchasing Agents'),
#    ('13-1021', 'Brokers, Cotton'),
#    ('13-1021', 'Brokers, Grain'),
#    ('13-1021', 'Buyers and Purchasing Agents, Farm Products'),
#    ('13-1021', 'Buyers, Farm Products'),
#    ('13-1021', 'Buyers, Fruit'),
#    ('13-1021', 'Buyers, Grain'),
#    ('13-1021', 'Buyers, Livestock'),
#    ('13-1021', 'Buyers, Tobacco'),
#    ('13-1021', 'Contractors, Tree Farm'),
#    ('13-1021', 'Cotton Brokers'),
#    ('13-1021', 'Farm Products, Buyers'),
#    ('13-1021', 'Farm Products, Purchasing Agents'),
#    ('13-1021', 'Fruit Buyers'),
#    ('13-1021', 'Grain Brokers'),
#    ('13-1021', 'Grain Buyers'),
#    ('13-1021', 'Grain Market Operators'),
#    ('13-1021', 'Livestock Buyers'),
#    ('13-1021', 'Operators, Grain Market'),
#    ('13-1021', 'Purchasing Agents, Farm Products'),
#    ('13-1021', 'Tobacco Buyers'),
#    ('13-1021', 'Tree Farm Contractors'),
#    ('13-1022', 'Assistant Wholesale and Retail Buyers, Except Farm Products'),
#    ('13-1022', 'Buyers, Except Farm Products, Assistant Wholesale and Retail'),
#    ('13-1022', 'Buyers, Gold'),
#    ('13-1022', 'Buyers, Merchandise'),
#    ('13-1022', 'Gold Buyers'),
#    ('13-1022', 'Merchandise Buyers'),
#    ('13-1022', 'Retail Buyers, Except Farm Products'),
#    ('13-1022', 'Wholesale and Retail Buyers, Except Farm Products'),
#    ('13-1022', 'Wholesale Buyers, Except Farm Products'),
#    ('13-1023',
#     'Agents, Purchasing, Except Wholesale, Retail, and Farm Products'),
#    ('13-1023', 'Buyers, Radio Time'),
#    ('13-1023', 'Equipment, Supplies, and Tools Purchasing Agents'),
#    ('13-1023', 'Purchasing Agents, Equipment, Supplies, and Tools'),
#    ('13-1023',
#     'Purchasing Agents, Except Wholesale, Retail, and Farm Products'),
#    ('13-1023', 'Radio Time Buyers'),
#    ('13-1030', 'Claims Adjusters, Appraisers, Examiners, and Investigators'),
#    ('13-1031', 'Adjusters, Claims'),
#    ('13-1031', 'Adjusters, Fire Claims'),
#    ('13-1031', 'Adjusters, Health Insurance'),
#    ('13-1031', 'Claims Adjusters'),
#    ('13-1031', 'Claims Adjusters, Examiners, and Investigators'),
#    ('13-1031', 'Claims Examiners'),
#    ('13-1031', 'Claims Investigators'),
#    ('13-1031', 'Examiners, Claims'),
#    ('13-1031', 'Examiners, Property and Casualty Insurance Claims'),
#    ('13-1031', 'Fire Claims Adjusters'),
#    ('13-1031', 'Health Insurance Adjusters'),
#    ('13-1031', 'Investigators, Claims'),
#    ('13-1031', 'Property and Casualty Insurance Claims Examiners'),
#    ('13-1032', 'Appraisers, Automobile Damage'),
#    ('13-1032', 'Appraisers, Vehicle Damage'),
#    ('13-1032', 'Auto Damage Insurance Appraisers'),
#    ('13-1032', 'Automobile Damage Appraisers'),
#    ('13-1032', 'Insurance Appraisers, Auto Damage'),
#    ('13-1032', 'Vehicle Damage Appraisers'),
#    ('13-1040', 'Compliance Officers'),
#    ('13-1041', 'Compliance Officers'),
#    ('13-1041', "Driver's License Examiners"),
#    ('13-1041', 'Environmental Compliance Inspectors'),
#    ('13-1041', 'Equal Employment Opportunity Officers'),
#    ('13-1041', "Examiners, Driver's License"),
#    ('13-1041', 'Inspectors, Environmental Compliance'),
#    ('13-1041', 'Officers, Compliance'),
#    ('13-1041', 'Officers, Equal Employment Opportunity'),
#    ('13-1050', 'Cost Estimators'),
#    ('13-1051', 'Construction Job Cost Estimators'),
#    ('13-1051', 'Cost Estimators'),
#    ('13-1051', 'Crating and Moving Estimators'),
#    ('13-1051', 'Estimators, Construction Job Cost'),
#    ('13-1051', 'Estimators, Cost'),
#    ('13-1051', 'Estimators, Crating and Moving'),
#    ('13-1051', 'Estimators, Production Cost'),
#    ('13-1051', 'Production Cost Estimators'),
#    ('13-1070', 'Human Resources Workers'),
#    ('13-1071', 'Coordinators, Staffing'),
#    ('13-1071', 'Generalists, Human Resources'),
#    ('13-1071', 'Human Resources Generalists'),
#    ('13-1071', 'Human Resources Specialists'),
#    ('13-1071', 'Personnel Recruiters'),
#    ('13-1071', 'Recruiters, Personnel'),
#    ('13-1071', 'Specialists, Human Resources'),
#    ('13-1071', 'Staffing Coordinators'),
#    ('13-1074', 'Contractors, Farm Labor'),
#    ('13-1074', 'Contractors, Harvesting'),
#    ('13-1074', 'Farm Labor Contractors'),
#    ('13-1074', 'Harvesting Contractors'),
#    ('13-1075', 'Consultants, Labor Relations'),
#    ('13-1075', 'Employee Relations Specialists'),
#    ('13-1075', 'Labor Relations Consultants'),
#    ('13-1075', 'Labor Relations Specialists'),
#    ('13-1075', 'Representatives, Union'),
#    ('13-1075', 'Specialists, Employee Relations'),
#    ('13-1075', 'Specialists, Labor Relations'),
#    ('13-1075', 'Union Representatives'),
#    ('13-1080', 'Logisticians'),
#    ('13-1081', 'Analysts, Logistics'),
#    ('13-1081', 'Logisticians'),
#    ('13-1081', 'Logistics Analysts'),
#    ('13-1081', 'Logistics Planners'),
#    ('13-1081', 'Logistics Specialists'),
#    ('13-1081', 'Planners, Logistics'),
#    ('13-1081', 'Specialists, Logistics'),
#    ('13-1110', 'Management Analysts'),
#    ('13-1111', 'Analysts, Business Management'),
#    ('13-1111', 'Analysts, Industrial'),
#    ('13-1111', 'Analysts, Management'),
#    ('13-1111', 'Analysts, Program'),
#    ('13-1111', 'Business Management Analysts'),
#    ('13-1111', 'Business Process Consultants'),
#    ('13-1111', 'Consultants, Business Process'),
#    ('13-1111', 'Consultants, Management'),
#    ('13-1111', 'Industrial Analysts'),
#    ('13-1111', 'Management Analysts'),
#    ('13-1111', 'Management Consultants'),
#    ('13-1111', 'Program Analysts'),
#    ('13-1120', 'Meeting, Convention, and Event Planners'),
#    ('13-1121', 'Conference Planners'),
#    ('13-1121', 'Convention Planners'),
#    ('13-1121', 'Corporate Meeting Planners'),
#    ('13-1121', 'Event Planners'),
#    ('13-1121', 'Meeting Planners'),
#    ('13-1121', 'Meeting, Convention, and Event Planners'),
#    ('13-1121', 'Planners, Conference'),
#    ('13-1121', 'Planners, Convention'),
#    ('13-1121', 'Planners, Corporate Meeting'),
#    ('13-1121', 'Planners, Event'),
#    ('13-1121', 'Planners, Meeting'),
#    ('13-1121', 'Planners, Wedding'),
#    ('13-1121', 'Wedding Planners'),
#    ('13-1130', 'Fundraisers'),
#    ('13-1131', 'Campaign Fundraisers'),
#    ('13-1131', 'Donor Relations Officers'),
#    ('13-1131', 'Fundraisers'),
#    ('13-1131', 'Fundraisers, Campaign'),
#    ('13-1131', 'Fundraising Officers'),
#    ('13-1131', 'Officers, Donor Relations'),
#    ('13-1131', 'Officers, Fundraising'),
#    ('13-1140', 'Compensation, Benefits, and Job Analysis Specialists'),
#    ('13-1141', 'Analysts, Job'),
#    ('13-1141', 'Benefits Specialists'),
#    ('13-1141', 'Compensation Specialists'),
#    ('13-1141', 'Compensation, Benefits, and Job Analysis Specialists'),
#    ('13-1141', 'Employee Benefits Specialists'),
#    ('13-1141', 'Job Analysis Specialists'),
#    ('13-1141', 'Job Analysts'),
#    ('13-1141', 'Retirement Plan Specialists'),
#    ('13-1141', 'Specialists, Benefits'),
#    ('13-1141', 'Specialists, Compensation'),
#    ('13-1141', 'Specialists, Employee Benefits'),
#    ('13-1141', 'Specialists, Job Analysis'),
#    ('13-1141', 'Specialists, Retirement Plan'),
#    ('13-1150', 'Training and Development Specialists'),
#    ('13-1151', 'Computer Training Specialists'),
#    ('13-1151', 'Corporate Trainers'),
#    ('13-1151', 'Development Specialists'),
#    ('13-1151', 'Specialists, Computer Training'),
#    ('13-1151', 'Specialists, Development'),
#    ('13-1151', 'Specialists, Training'),
#    ('13-1151', 'Specialists, Workforce Development'),
#    ('13-1151', 'Trainers, Corporate'),
#    ('13-1151', 'Training and Development Specialists'),
#    ('13-1151', 'Training Specialists'),
#    ('13-1151', 'Workforce Development Specialists'),
#    ('13-1160', 'Market Research Analysts and Marketing Specialists'),
#    ('13-1161', 'Analysts, Market Research'),
#    ('13-1161', 'Consultants, Marketing'),
#    ('13-1161', 'Forecasters, Marketing'),
#    ('13-1161', 'Market Research Analysts'),
#    ('13-1161', 'Market Research Analysts and Marketing Specialists'),
#    ('13-1161', 'Market Research Specialists'),
#    ('13-1161', 'Marketing Consultants'),
#    ('13-1161', 'Marketing Forecasters'),
#    ('13-1161', 'Marketing Specialists'),
#    ('13-1161', 'Specialists, Market Research'),
#    ('13-1161', 'Specialists, Marketing'),
#    ('13-1190', 'Business Operations Specialists, Miscellaneous'),
#    ('13-1199', 'Business Operations Specialists, All Other'),
#    ('13-1199', 'Mystery Shoppers'),
#    ('13-1199', 'Pursers, Ship'),
#    ('13-1199', 'Ship Pursers'),
#    ('13-1199', 'Shoppers, Mystery'),
#    ('13-1199', 'Specialists, Business Operations, All Other')],
#   'label': 'Business Operations Specialists'},
#  '2': {'SOC': [('13-2010', 'Accountants and Auditors'),
#    ('13-2011', 'Accountants'),
#    ('13-2011', 'Accountants and Auditors'),
#    ('13-2011', 'Accountants, Certified Public'),
#    ('13-2011', 'Auditors'),
#    ('13-2011', 'Auditors, Field'),
#    ('13-2011', 'Auditors, Internal'),
#    ('13-2011', 'Certified Public Accountants'),
#    ('13-2011', 'Field Auditors'),
#    ('13-2011', 'Internal Auditors'),
#    ('13-2020', 'Appraisers and Assessors of Real Estate'),
#    ('13-2021', 'Appraisers and Assessors of Real Estate'),
#    ('13-2021', 'Appraisers of Real Estate'),
#    ('13-2021', 'Appraisers, Land'),
#    ('13-2021', 'Appraisers, Property'),
#    ('13-2021', 'Assessors of Real Estate'),
#    ('13-2021', 'Assessors, Tax'),
#    ('13-2021', 'Land Appraisers'),
#    ('13-2021', 'Property Appraisers'),
#    ('13-2021', 'Real Estate Appraisers'),
#    ('13-2021', 'Real Estate Assessors'),
#    ('13-2021', 'Tax Assessors'),
#    ('13-2030', 'Budget Analysts'),
#    ('13-2031', 'Analysts, Budget'),
#    ('13-2031', 'Analysts, Cost'),
#    ('13-2031', 'Budget Analysts'),
#    ('13-2031', 'Budget Examiners'),
#    ('13-2031', 'Budget Officers'),
#    ('13-2031', 'Cost Analysts'),
#    ('13-2031', 'Examiners, Budget'),
#    ('13-2031', 'Officers, Budget'),
#    ('13-2040', 'Credit Analysts'),
#    ('13-2041', 'Analysts, Credit'),
#    ('13-2041', 'Analysts, Credit Assessment'),
#    ('13-2041', 'Analysts, Credit Risk'),
#    ('13-2041', 'Credit Analysts'),
#    ('13-2041', 'Credit Assessment Analysts'),
#    ('13-2041', 'Credit Risk Analysts'),
#    ('13-2050', 'Financial Analysts and Advisors'),
#    ('13-2051', 'Analysts, Corporate Financial'),
#    ('13-2051', 'Analysts, Corporate Securities Research'),
#    ('13-2051', 'Analysts, Financial'),
#    ('13-2051', 'Analysts, Institutional Commodity'),
#    ('13-2051', 'Corporate Financial Analysts'),
#    ('13-2051', 'Corporate Securities Research Analysts'),
#    ('13-2051', 'Financial Analysts'),
#    ('13-2051', 'Institutional Commodity Analysts'),
#    ('13-2052', 'Advisers, Individual Pension'),
#    ('13-2052', 'Advisers, Personal Investment'),
#    ('13-2052', 'Advisors, Personal Financial'),
#    ('13-2052', 'Estate Planners'),
#    ('13-2052', 'Individual Pension Advisers'),
#    ('13-2052', 'Personal Financial Advisors'),
#    ('13-2052', 'Personal Investment Advisers'),
#    ('13-2052', 'Planners, Estate'),
#    ('13-2053', 'Analysts, Insurance'),
#    ('13-2053', 'Automobile and Property Underwriters'),
#    ('13-2053', 'Bond Underwriters'),
#    ('13-2053', 'Insurance Analysts'),
#    ('13-2053', 'Insurance Underwriters'),
#    ('13-2053', 'Underwriters, Automobile and Property'),
#    ('13-2053', 'Underwriters, Bond'),
#    ('13-2053', 'Underwriters, Insurance'),
#    ('13-2060', 'Financial Examiners'),
#    ('13-2061', 'Bank Examiners'),
#    ('13-2061', 'Examiners, Bank'),
#    ('13-2061', 'Examiners, Financial'),
#    ('13-2061', 'Examiners, Financial Compliance'),
#    ('13-2061', 'Financial Compliance Examiners'),
#    ('13-2061', 'Financial Examiners'),
#    ('13-2061', 'Home Mortgage Disclosure Act Specialists'),
#    ('13-2061', 'Specialists, Home Mortgage Disclosure Act'),
#    ('13-2070', 'Credit Counselors and Loan Officers'),
#    ('13-2071', 'Counselors, Credit'),
#    ('13-2071', 'Counselors, Debt Management'),
#    ('13-2071', 'Counselors, Loan'),
#    ('13-2071', 'Credit Counselors'),
#    ('13-2071', 'Debt Management Counselors'),
#    ('13-2071', 'Financial Assistance Advisors'),
#    ('13-2071', 'Loan Counselors'),
#    ('13-2072', 'Agents, Mortgage Loan'),
#    ('13-2072', 'Analysts, Collection'),
#    ('13-2072', 'Collection Analysts'),
#    ('13-2072', 'Commercial Lenders'),
#    ('13-2072', 'Lenders, Commercial'),
#    ('13-2072', 'Loan Officers'),
#    ('13-2072', 'Loan Reviewers'),
#    ('13-2072', 'Loan Servicing Officers'),
#    ('13-2072', 'Loan Underwriters'),
#    ('13-2072', 'Mortgage Loan Agents'),
#    ('13-2072', 'Mortgage Loan Officers'),
#    ('13-2072', 'Officers, Loan'),
#    ('13-2072', 'Officers, Loan Servicing'),
#    ('13-2072', 'Officers, Mortgage Loan'),
#    ('13-2072', 'Officers, Real Estate Loan'),
#    ('13-2072', 'Real Estate Loan Officers'),
#    ('13-2072', 'Reviewers, Loan'),
#    ('13-2072', 'Underwriters, Loan'),
#    ('13-2080', 'Tax Examiners, Collectors and Preparers, and Revenue Agents'),
#    ('13-2081', 'Agents, Internal Revenue Service'),
#    ('13-2081', 'Agents, Revenue'),
#    ('13-2081', 'Collectors, Revenue'),
#    ('13-2081', 'Collectors, Tax'),
#    ('13-2081', 'Examiners, Tax'),
#    ('13-2081', 'Internal Revenue Service Agents'),
#    ('13-2081', 'Investigators, Tax'),
#    ('13-2081', 'Revenue Agents'),
#    ('13-2081', 'Revenue Collectors'),
#    ('13-2081', 'Tax Collectors'),
#    ('13-2081', 'Tax Examiners'),
#    ('13-2081', 'Tax Examiners and Collectors, and Revenue Agents'),
#    ('13-2081', 'Tax Investigators'),
#    ('13-2082', 'Advisors, Income Tax'),
#    ('13-2082', 'Consultants, Licensed Tax'),
#    ('13-2082', 'Income Tax Advisors'),
#    ('13-2082', 'Income Tax Preparers'),
#    ('13-2082', 'Licensed Tax Consultants'),
#    ('13-2082', 'Preparers, Income Tax'),
#    ('13-2082', 'Preparers, Tax'),
#    ('13-2082', 'Tax Preparers'),
#    ('13-2090', 'Financial Specialists, Miscellaneous'),
#    ('13-2099', 'Bail Bondsmen'),
#    ('13-2099', 'Bondsmen, Bail'),
#    ('13-2099', 'Executors of Estate'),
#    ('13-2099', 'Financial Specialists, All Other'),
#    ('13-2099', 'Foreign Exchange Traders'),
#    ('13-2099', 'Specialists, Financial, All Other'),
#    ('13-2099', 'Traders, Foreign Exchange')],
#   'label': 'Financial Specialists'}}

# %%
results = []
for first_key in sorted(soc_dict.keys()):
    for second_key in sorted(soc_dict[first_key]):
        if second_key == "0":
            continue
        for occupation in sorted(soc_dict[first_key][second_key]["SOC"]):
            results.append((soc_dict[first_key]["0"]["label"], soc_dict[first_key][second_key]["label"], occupation[1]))
           # print (soc_dict[first_key]["0"]["label"], soc_dict[first_key][second_key]["label"], occupation[1])

# %%
df = pd.DataFrame(data = results, columns=['Kind', 'Type of Job', 'Occupation']) ##change names
df
# Out:
#                                Kind  \
# 0            Management Occupations
# 1            Management Occupations
# 2            Management Occupations
# 3            Management Occupations
# 4            Management Occupations
# 5            Management Occupations
# 6            Management Occupations
# 7            Management Occupations
# 8            Management Occupations
